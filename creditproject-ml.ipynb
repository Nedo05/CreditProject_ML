# %%
# Imports and data loading
# !pip install -U imbalanced-learn==0.10.1 scikit-learn==1.2.2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import optuna
import joblib

from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.metrics import precision_recall_curve, classification_report, fbeta_score, make_scorer
from sklearn.preprocessing import StandardScaler
from sklearn.impute import KNNImputer
from sklearn.impute import SimpleImputer

from imblearn.over_sampling import SMOTE

from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression

import warnings
warnings.filterwarnings('ignore')

# Load datasets
df_train = pd.read_csv('/kaggle/input/creditcsv/cs-training.csv', index_col=0)
df_test = pd.read_csv('/kaggle/input/creditcsv/cs-test.csv', index_col=0)
df_submission = pd.read_csv('/kaggle/input/creditcsv/sampleEntry.csv')

# Basic info
print(df_train.info())
print(df_train.head())
# Out:
# Requirement already satisfied: imbalanced-learn==0.10.1 in /usr/local/lib/python3.11/dist-packages (0.10.1)
# Requirement already satisfied: scikit-learn==1.2.2 in /usr/local/lib/python3.11/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn==0.10.1) (1.26.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn==0.10.1) (1.15.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn==0.10.1) (1.5.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn==0.10.1) (3.6.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->imbalanced-learn==0.10.1) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->imbalanced-learn==0.10.1) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->imbalanced-learn==0.10.1) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->imbalanced-learn==0.10.1) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->imbalanced-learn==0.10.1) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->imbalanced-learn==0.10.1) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17.3->imbalanced-learn==0.10.1) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17.3->imbalanced-learn==0.10.1) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17.3->imbalanced-learn==0.10.1) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17.3->imbalanced-learn==0.10.1) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17.3->imbalanced-learn==0.10.1) (2024.2.0)
# <class 'pandas.core.frame.DataFrame'>
# Index: 150000 entries, 1 to 150000
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   SeriousDlqin2yrs                      150000 non-null  int64
#  1   RevolvingUtilizationOfUnsecuredLines  150000 non-null  float64
#  2   age                                   150000 non-null  int64
#  3   NumberOfTime30-59DaysPastDueNotWorse  150000 non-null  int64
#  4   DebtRatio                             150000 non-null  float64
#  5   MonthlyIncome                         120269 non-null  float64
#  6   NumberOfOpenCreditLinesAndLoans       150000 non-null  int64
#  7   NumberOfTimes90DaysLate               150000 non-null  int64
#  8   NumberRealEstateLoansOrLines          150000 non-null  int64
#  9   NumberOfTime60-89DaysPastDueNotWorse  150000 non-null  int64
#  10  NumberOfDependents                    146076 non-null  float64
# dtypes: float64(4), int64(7)
# memory usage: 13.7 MB
# None
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 1                 1                              0.766127   45
# 2                 0                              0.957151   40
# 3                 0                              0.658180   38
# 4                 0                              0.233810   30
# 5                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 1                                     2   0.802982         9120.0
# 2                                     0   0.121876         2600.0
# 3                                     1   0.085113         3042.0
# 4                                     0   0.036050         3300.0
# 5                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 1                               13                        0
# 2                                4                        0
# 3                                2                        1
# 4                                5                        0
# 5                                7                        0
#
#    NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# 1                             6                                     0
# 2                             0                                     0
# 3                             0                                     0
# 4                             0                                     0
# 5                             1                                     0
#
#    NumberOfDependents
# 1                 2.0
# 2                 1.0
# 3                 0.0
# 4                 0.0
# 5                 0.0

# %%
# Advanced data preprocessing and feature engineering

# Impute missing with KNN
imputer = KNNImputer(n_neighbors=5)
df_train_imputed = df_train.copy()
df_train_imputed[['MonthlyIncome', 'NumberOfDependents']] = imputer.fit_transform(df_train_imputed[['MonthlyIncome', 'NumberOfDependents']])

df_test_imputed = df_test.copy()
df_test_imputed[['MonthlyIncome', 'NumberOfDependents']] = imputer.transform(df_test_imputed[['MonthlyIncome', 'NumberOfDependents']])

# Feature engineering example: Debt to income ratio squared, Age buckets
df_train_imputed['DebtRatio_sq'] = df_train_imputed['DebtRatio'] ** 2
df_train_imputed['Age_bucket'] = pd.cut(df_train_imputed['age'], bins=[0,25,40,60,100], labels=[0,1,2,3])

df_test_imputed['DebtRatio_sq'] = df_test_imputed['DebtRatio'] ** 2
df_test_imputed['Age_bucket'] = pd.cut(df_test_imputed['age'], bins=[0,25,40,60,100], labels=[0,1,2,3])

# %%
# Prepare data for modeling
target = 'SeriousDlqin2yrs'
features = [c for c in df_train.columns if c != target]

# Si hay categóricas, hacer dummy:
X = pd.get_dummies(df_train[features])

y = df_train[target]

# Imputar faltantes con mediana (en columnas numéricas)
imputer = SimpleImputer(strategy='median')
X_imputed = imputer.fit_transform(X)

# Split
X_train, X_val, y_train, y_val = train_test_split(
    X_imputed, y, test_size=0.2, random_state=42, stratify=y
)

# Escalar
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

# Balance con SMOTE
smote = SMOTE(random_state=42)
X_train_bal, y_train_bal = smote.fit_resample(X_train_scaled, y_train)

# %%
# Define custom F2 scorer and threshold finder

def f2_scorer(y_true, y_pred):
    return fbeta_score(y_true, y_pred, beta=2)

def find_best_threshold_f2(y_true, y_prob):
    precision, recall, thresholds = precision_recall_curve(y_true, y_prob)
    f2_scores = 5 * (precision * recall) / (4 * precision + recall + 1e-9)
    best_idx = np.argmax(f2_scores)
    return thresholds[best_idx], f2_scores[best_idx]

# %%
# Hyperparameter tuning with Optuna for LightGBM

def objective(trial):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 2000),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'num_leaves': trial.suggest_int('num_leaves', 20, 150),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 1.0),
        'random_state': 42,
        'n_jobs': -1,
        'verbose': -1
    }
    
    model = LGBMClassifier(**param)
    model.fit(X_train_bal, y_train_bal)
    y_val_prob = model.predict_proba(X_val_scaled)[:, 1]
    
    best_thresh, best_f2 = find_best_threshold_f2(y_val, y_val_prob)
    return best_f2

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

print("Best params:", study.best_params)
print("Best F2 score:", study.best_value)
# Out:
# [I 2025-06-30 20:56:15,176] A new study created in memory with name: no-name-032dea03-7daf-4503-b7f8-554379907aa5
# [I 2025-06-30 20:56:44,827] Trial 0 finished with value: 0.4424778757954692 and parameters: {'n_estimators': 795, 'learning_rate': 0.2513311316041554, 'num_leaves': 141, 'max_depth': 15, 'min_child_samples': 27, 'subsample': 0.5503463112180885, 'colsample_bytree': 0.7720312974141961, 'reg_alpha': 0.5920373394551252, 'reg_lambda': 0.4042993521371503}. Best is trial 0 with value: 0.4424778757954692.
# [I 2025-06-30 20:56:57,458] Trial 1 finished with value: 0.500598175264446 and parameters: {'n_estimators': 652, 'learning_rate': 0.06678252952611591, 'num_leaves': 44, 'max_depth': 14, 'min_child_samples': 43, 'subsample': 0.7188810555394671, 'colsample_bytree': 0.5386151140952329, 'reg_alpha': 0.1548663454298579, 'reg_lambda': 0.8265665802233543}. Best is trial 1 with value: 0.500598175264446.
# [I 2025-06-30 20:57:13,869] Trial 2 finished with value: 0.4995820983271784 and parameters: {'n_estimators': 675, 'learning_rate': 0.024757218536221714, 'num_leaves': 85, 'max_depth': 8, 'min_child_samples': 32, 'subsample': 0.5656326125836859, 'colsample_bytree': 0.9966886824193895, 'reg_alpha': 0.7745077035086846, 'reg_lambda': 0.20702465078918408}. Best is trial 1 with value: 0.500598175264446.
# [I 2025-06-30 20:57:17,911] Trial 3 finished with value: 0.48022390777762514 and parameters: {'n_estimators': 139, 'learning_rate': 0.2955765223124105, 'num_leaves': 99, 'max_depth': 15, 'min_child_samples': 66, 'subsample': 0.5135180138100431, 'colsample_bytree': 0.9528872273323422, 'reg_alpha': 0.9688152634140286, 'reg_lambda': 0.561377346520424}. Best is trial 1 with value: 0.500598175264446.
# [I 2025-06-30 20:57:30,379] Trial 4 finished with value: 0.5062367784550147 and parameters: {'n_estimators': 365, 'learning_rate': 0.01941554779228626, 'num_leaves': 93, 'max_depth': 15, 'min_child_samples': 73, 'subsample': 0.9686349676389248, 'colsample_bytree': 0.7808910511114542, 'reg_alpha': 0.21901059772670506, 'reg_lambda': 0.09829577828977887}. Best is trial 4 with value: 0.5062367784550147.
# [I 2025-06-30 20:58:12,147] Trial 5 finished with value: 0.4870961043062267 and parameters: {'n_estimators': 1114, 'learning_rate': 0.030620534261270906, 'num_leaves': 150, 'max_depth': 12, 'min_child_samples': 70, 'subsample': 0.7711979494444248, 'colsample_bytree': 0.5032687734594301, 'reg_alpha': 0.09967859848708993, 'reg_lambda': 0.4700505098515033}. Best is trial 4 with value: 0.5062367784550147.
# [I 2025-06-30 20:59:03,056] Trial 6 finished with value: 0.49881661018011686 and parameters: {'n_estimators': 1376, 'learning_rate': 0.013309662716979502, 'num_leaves': 131, 'max_depth': 14, 'min_child_samples': 61, 'subsample': 0.794590535464947, 'colsample_bytree': 0.7987398641625199, 'reg_alpha': 0.6062720229283056, 'reg_lambda': 0.31938177282069713}. Best is trial 4 with value: 0.5062367784550147.
# [I 2025-06-30 20:59:55,781] Trial 7 finished with value: 0.4770087288130584 and parameters: {'n_estimators': 1596, 'learning_rate': 0.04335667304985006, 'num_leaves': 122, 'max_depth': 15, 'min_child_samples': 64, 'subsample': 0.6065847821043691, 'colsample_bytree': 0.6871536533039597, 'reg_alpha': 0.5496570340080518, 'reg_lambda': 0.022211377952909506}. Best is trial 4 with value: 0.5062367784550147.
# [I 2025-06-30 21:00:40,243] Trial 8 finished with value: 0.5024226608996145 and parameters: {'n_estimators': 1390, 'learning_rate': 0.01714166678129726, 'num_leaves': 106, 'max_depth': 11, 'min_child_samples': 35, 'subsample': 0.7368522643341637, 'colsample_bytree': 0.6791854998838855, 'reg_alpha': 0.30544978866616734, 'reg_lambda': 0.8767279095043177}. Best is trial 4 with value: 0.5062367784550147.
# [I 2025-06-30 21:01:02,401] Trial 9 finished with value: 0.4846269958181126 and parameters: {'n_estimators': 1896, 'learning_rate': 0.08664786565480039, 'num_leaves': 135, 'max_depth': 5, 'min_child_samples': 99, 'subsample': 0.5100884484783801, 'colsample_bytree': 0.8693279306906301, 'reg_alpha': 0.7845116266940658, 'reg_lambda': 0.8998295788777761}. Best is trial 4 with value: 0.5062367784550147.
# [I 2025-06-30 21:01:03,668] Trial 10 finished with value: 0.49265237263561523 and parameters: {'n_estimators': 125, 'learning_rate': 0.1502820290238607, 'num_leaves': 66, 'max_depth': 3, 'min_child_samples': 5, 'subsample': 0.9927768712515749, 'colsample_bytree': 0.6317944378657089, 'reg_alpha': 0.3291721163248099, 'reg_lambda': 0.01114741801235844}. Best is trial 4 with value: 0.5062367784550147.
# [I 2025-06-30 21:01:39,076] Trial 11 finished with value: 0.5010128777160939 and parameters: {'n_estimators': 1168, 'learning_rate': 0.010525712899601046, 'num_leaves': 96, 'max_depth': 11, 'min_child_samples': 89, 'subsample': 0.9321914642032663, 'colsample_bytree': 0.715165186809825, 'reg_alpha': 0.2761611850809397, 'reg_lambda': 0.6980699233735267}. Best is trial 4 with value: 0.5062367784550147.
# [I 2025-06-30 21:01:54,626] Trial 12 finished with value: 0.4919520274829363 and parameters: {'n_estimators': 452, 'learning_rate': 0.01813273447466726, 'num_leaves': 110, 'max_depth': 10, 'min_child_samples': 46, 'subsample': 0.8675100856882059, 'colsample_bytree': 0.6249229993059255, 'reg_alpha': 0.358710532816519, 'reg_lambda': 0.9733486645022953}. Best is trial 4 with value: 0.5062367784550147.
# [I 2025-06-30 21:02:29,255] Trial 13 finished with value: 0.49617174568459443 and parameters: {'n_estimators': 1570, 'learning_rate': 0.020306791601155658, 'num_leaves': 71, 'max_depth': 8, 'min_child_samples': 85, 'subsample': 0.6749383299656815, 'colsample_bytree': 0.8398513103789431, 'reg_alpha': 0.005285156123375545, 'reg_lambda': 0.6703221756752189}. Best is trial 4 with value: 0.5062367784550147.
# [I 2025-06-30 21:02:44,440] Trial 14 finished with value: 0.5080373828774768 and parameters: {'n_estimators': 923, 'learning_rate': 0.04128170372948573, 'num_leaves': 23, 'max_depth': 12, 'min_child_samples': 16, 'subsample': 0.8421160573955445, 'colsample_bytree': 0.6482474525447863, 'reg_alpha': 0.404400940884538, 'reg_lambda': 0.2114008092046994}. Best is trial 14 with value: 0.5080373828774768.
# [I 2025-06-30 21:02:52,176] Trial 15 finished with value: 0.5042283295025368 and parameters: {'n_estimators': 375, 'learning_rate': 0.03937335472032842, 'num_leaves': 22, 'max_depth': 13, 'min_child_samples': 8, 'subsample': 0.8549347500702112, 'colsample_bytree': 0.5882920468297612, 'reg_alpha': 0.39052709033640987, 'reg_lambda': 0.18761078536744574}. Best is trial 14 with value: 0.5080373828774768.
# [I 2025-06-30 21:03:05,848] Trial 16 finished with value: 0.504515842162205 and parameters: {'n_estimators': 903, 'learning_rate': 0.08371956983182526, 'num_leaves': 22, 'max_depth': 13, 'min_child_samples': 17, 'subsample': 0.9888335397986351, 'colsample_bytree': 0.8977353183908912, 'reg_alpha': 0.19401176544866217, 'reg_lambda': 0.17189792862701503}. Best is trial 14 with value: 0.5080373828774768.
# [I 2025-06-30 21:03:14,509] Trial 17 finished with value: 0.5047519266625495 and parameters: {'n_estimators': 418, 'learning_rate': 0.030794791899972463, 'num_leaves': 48, 'max_depth': 9, 'min_child_samples': 79, 'subsample': 0.9032809658052188, 'colsample_bytree': 0.7554542599597415, 'reg_alpha': 0.4472877237637986, 'reg_lambda': 0.30027136086419076}. Best is trial 14 with value: 0.5080373828774768.
# [I 2025-06-30 21:03:34,951] Trial 18 finished with value: 0.4976542761297723 and parameters: {'n_estimators': 889, 'learning_rate': 0.05349055204786311, 'num_leaves': 67, 'max_depth': 12, 'min_child_samples': 54, 'subsample': 0.8298536050079535, 'colsample_bytree': 0.8173203816299474, 'reg_alpha': 0.2229103920748709, 'reg_lambda': 0.08653153951111203}. Best is trial 14 with value: 0.5080373828774768.
# [I 2025-06-30 21:03:44,177] Trial 19 finished with value: 0.49420127167906847 and parameters: {'n_estimators': 556, 'learning_rate': 0.11463553742674601, 'num_leaves': 46, 'max_depth': 7, 'min_child_samples': 17, 'subsample': 0.9382466934413878, 'colsample_bytree': 0.7016804729768921, 'reg_alpha': 0.026943451669673713, 'reg_lambda': 0.3299004852998364}. Best is trial 14 with value: 0.5080373828774768.
# [I 2025-06-30 21:04:34,426] Trial 20 finished with value: 0.4918032783866578 and parameters: {'n_estimators': 1976, 'learning_rate': 0.028793699987706096, 'num_leaves': 84, 'max_depth': 13, 'min_child_samples': 52, 'subsample': 0.8993728250734336, 'colsample_bytree': 0.6293345222702169, 'reg_alpha': 0.46254613863479793, 'reg_lambda': 0.13993020736121065}. Best is trial 14 with value: 0.5080373828774768.
# [I 2025-06-30 21:04:40,400] Trial 21 finished with value: 0.5023303984555081 and parameters: {'n_estimators': 318, 'learning_rate': 0.037916900360988735, 'num_leaves': 40, 'max_depth': 9, 'min_child_samples': 76, 'subsample': 0.9271694522331019, 'colsample_bytree': 0.7404879433928678, 'reg_alpha': 0.4580087869167485, 'reg_lambda': 0.26800680973724955}. Best is trial 14 with value: 0.5080373828774768.
# [I 2025-06-30 21:04:47,894] Trial 22 finished with value: 0.5012412380144103 and parameters: {'n_estimators': 328, 'learning_rate': 0.023087876771617135, 'num_leaves': 54, 'max_depth': 10, 'min_child_samples': 78, 'subsample': 0.8913218000841507, 'colsample_bytree': 0.765716482366123, 'reg_alpha': 0.6742352911094661, 'reg_lambda': 0.3986615119116064}. Best is trial 14 with value: 0.5080373828774768.
# [I 2025-06-30 21:04:55,664] Trial 23 finished with value: 0.49929328591215644 and parameters: {'n_estimators': 540, 'learning_rate': 0.05240751258958879, 'num_leaves': 34, 'max_depth': 6, 'min_child_samples': 100, 'subsample': 0.8197402671634297, 'colsample_bytree': 0.73960303502736, 'reg_alpha': 0.3846522572921814, 'reg_lambda': 0.09616697640603535}. Best is trial 14 with value: 0.5080373828774768.
# [I 2025-06-30 21:05:01,034] Trial 24 finished with value: 0.506026599857609 and parameters: {'n_estimators': 251, 'learning_rate': 0.03217898793893462, 'num_leaves': 31, 'max_depth': 10, 'min_child_samples': 79, 'subsample': 0.9704242256134307, 'colsample_bytree': 0.5713771996964812, 'reg_alpha': 0.45457848022283637, 'reg_lambda': 0.2541459018995121}. Best is trial 14 with value: 0.5080373828774768.
# [I 2025-06-30 21:05:04,155] Trial 25 finished with value: 0.510722558169518 and parameters: {'n_estimators': 148, 'learning_rate': 0.014759687900339572, 'num_leaves': 32, 'max_depth': 11, 'min_child_samples': 90, 'subsample': 0.9670686165429271, 'colsample_bytree': 0.5798120470232503, 'reg_alpha': 0.27143603497173674, 'reg_lambda': 0.24292244988332923}. Best is trial 25 with value: 0.510722558169518.
# [I 2025-06-30 21:05:08,037] Trial 26 finished with value: 0.5113213165472529 and parameters: {'n_estimators': 140, 'learning_rate': 0.013270927754214963, 'num_leaves': 57, 'max_depth': 12, 'min_child_samples': 92, 'subsample': 0.9690468670999288, 'colsample_bytree': 0.6527930641544551, 'reg_alpha': 0.11988764034138266, 'reg_lambda': 0.08748061771975146}. Best is trial 26 with value: 0.5113213165472529.
# [I 2025-06-30 21:05:11,869] Trial 27 finished with value: 0.5104281006961693 and parameters: {'n_estimators': 136, 'learning_rate': 0.010856064250666524, 'num_leaves': 61, 'max_depth': 11, 'min_child_samples': 91, 'subsample': 0.6942476148562995, 'colsample_bytree': 0.5950055767021656, 'reg_alpha': 0.0977289819226877, 'reg_lambda': 0.5438119523928556}. Best is trial 26 with value: 0.5113213165472529.
# [I 2025-06-30 21:05:17,592] Trial 28 finished with value: 0.5084811099594417 and parameters: {'n_estimators': 199, 'learning_rate': 0.010197237475605466, 'num_leaves': 58, 'max_depth': 11, 'min_child_samples': 90, 'subsample': 0.666428871246489, 'colsample_bytree': 0.5823580219993165, 'reg_alpha': 0.11602813711693649, 'reg_lambda': 0.55626411182646}. Best is trial 26 with value: 0.5113213165472529.
# [I 2025-06-30 21:05:20,793] Trial 29 finished with value: 0.5099128285255964 and parameters: {'n_estimators': 100, 'learning_rate': 0.013467962288572952, 'num_leaves': 76, 'max_depth': 11, 'min_child_samples': 92, 'subsample': 0.6834700344024666, 'colsample_bytree': 0.5413571391364868, 'reg_alpha': 0.07678284331412952, 'reg_lambda': 0.4797658970924692}. Best is trial 26 with value: 0.5113213165472529.
# [I 2025-06-30 21:05:34,310] Trial 30 finished with value: 0.49885233329200696 and parameters: {'n_estimators': 541, 'learning_rate': 0.01146077658931107, 'num_leaves': 58, 'max_depth': 8, 'min_child_samples': 95, 'subsample': 0.6140072062604132, 'colsample_bytree': 0.6666397308572418, 'reg_alpha': 0.2653905941053869, 'reg_lambda': 0.37267242179503773}. Best is trial 26 with value: 0.5113213165472529.
# [I 2025-06-30 21:05:37,616] Trial 31 finished with value: 0.5094768761236212 and parameters: {'n_estimators': 109, 'learning_rate': 0.014404790242228871, 'num_leaves': 77, 'max_depth': 11, 'min_child_samples': 84, 'subsample': 0.6951044182968577, 'colsample_bytree': 0.5327843728207874, 'reg_alpha': 0.06745654375309378, 'reg_lambda': 0.49457337571604265}. Best is trial 26 with value: 0.5113213165472529.
# [I 2025-06-30 21:05:45,519] Trial 32 finished with value: 0.5056924513603036 and parameters: {'n_estimators': 262, 'learning_rate': 0.01414973021207923, 'num_leaves': 81, 'max_depth': 12, 'min_child_samples': 93, 'subsample': 0.6350475185089706, 'colsample_bytree': 0.536037055046688, 'reg_alpha': 0.15254455652194987, 'reg_lambda': 0.6827444559644664}. Best is trial 26 with value: 0.5113213165472529.
# [I 2025-06-30 21:05:51,612] Trial 33 finished with value: 0.5056430053419024 and parameters: {'n_estimators': 224, 'learning_rate': 0.01480783648417492, 'num_leaves': 62, 'max_depth': 10, 'min_child_samples': 84, 'subsample': 0.7208924184786232, 'colsample_bytree': 0.6009553582272215, 'reg_alpha': 0.058719261691719, 'reg_lambda': 0.6143296516675305}. Best is trial 26 with value: 0.5113213165472529.
# [I 2025-06-30 21:06:10,893] Trial 34 finished with value: 0.4942263276493006 and parameters: {'n_estimators': 746, 'learning_rate': 0.01290742795046359, 'num_leaves': 74, 'max_depth': 9, 'min_child_samples': 94, 'subsample': 0.7732793884740203, 'colsample_bytree': 0.5533318081219051, 'reg_alpha': 0.1493149931944307, 'reg_lambda': 0.4633616623245914}. Best is trial 26 with value: 0.5113213165472529.
# [I 2025-06-30 21:06:14,014] Trial 35 finished with value: 0.5124815301522255 and parameters: {'n_estimators': 123, 'learning_rate': 0.0165281787783598, 'num_leaves': 52, 'max_depth': 14, 'min_child_samples': 86, 'subsample': 0.5789769182814014, 'colsample_bytree': 0.6116843722507829, 'reg_alpha': 0.18375368059260366, 'reg_lambda': 0.7619301967936067}. Best is trial 35 with value: 0.5124815301522255.
# [I 2025-06-30 21:06:26,622] Trial 36 finished with value: 0.5088020606647042 and parameters: {'n_estimators': 653, 'learning_rate': 0.02152488231784253, 'num_leaves': 39, 'max_depth': 14, 'min_child_samples': 70, 'subsample': 0.5414616550139191, 'colsample_bytree': 0.6111595658619081, 'reg_alpha': 0.20500775089874346, 'reg_lambda': 0.7851792990375019}. Best is trial 35 with value: 0.5124815301522255.
# [I 2025-06-30 21:06:37,314] Trial 37 finished with value: 0.5038384136518921 and parameters: {'n_estimators': 451, 'learning_rate': 0.017967545438041667, 'num_leaves': 49, 'max_depth': 13, 'min_child_samples': 86, 'subsample': 0.5755921341919399, 'colsample_bytree': 0.5150478032775385, 'reg_alpha': 0.2562424857597667, 'reg_lambda': 0.769066905339058}. Best is trial 35 with value: 0.5124815301522255.
# [I 2025-06-30 21:06:41,619] Trial 38 finished with value: 0.512859650164927 and parameters: {'n_estimators': 215, 'learning_rate': 0.016164681015374455, 'num_leaves': 33, 'max_depth': 14, 'min_child_samples': 100, 'subsample': 0.6421631816787918, 'colsample_bytree': 0.6570997703960657, 'reg_alpha': 0.13231170133425174, 'reg_lambda': 0.5282284076568279}. Best is trial 38 with value: 0.512859650164927.
# [I 2025-06-30 21:06:46,683] Trial 39 finished with value: 0.5104498482030643 and parameters: {'n_estimators': 275, 'learning_rate': 0.02525980193086057, 'num_leaves': 32, 'max_depth': 14, 'min_child_samples': 100, 'subsample': 0.5521051174416495, 'colsample_bytree': 0.6571320822697362, 'reg_alpha': 0.17334639846025424, 'reg_lambda': 0.7460944038205326}. Best is trial 38 with value: 0.512859650164927.
# [I 2025-06-30 21:06:51,082] Trial 40 finished with value: 0.5106613099649575 and parameters: {'n_estimators': 198, 'learning_rate': 0.016502049904114732, 'num_leaves': 39, 'max_depth': 15, 'min_child_samples': 71, 'subsample': 0.5766182613244519, 'colsample_bytree': 0.5626788679294185, 'reg_alpha': 0.14410051653605743, 'reg_lambda': 0.6319070894702606}. Best is trial 38 with value: 0.512859650164927.
# [I 2025-06-30 21:06:55,779] Trial 41 finished with value: 0.5123428036187164 and parameters: {'n_estimators': 223, 'learning_rate': 0.016237881833559047, 'num_leaves': 38, 'max_depth': 15, 'min_child_samples': 71, 'subsample': 0.5932405733864927, 'colsample_bytree': 0.5624124112299321, 'reg_alpha': 0.1395675303828722, 'reg_lambda': 0.6181108818691423}. Best is trial 38 with value: 0.512859650164927.
# [I 2025-06-30 21:07:02,271] Trial 42 finished with value: 0.5062550293259901 and parameters: {'n_estimators': 384, 'learning_rate': 0.02535643563328427, 'num_leaves': 27, 'max_depth': 15, 'min_child_samples': 59, 'subsample': 0.6377297188335569, 'colsample_bytree': 0.6439515032694022, 'reg_alpha': 0.233929766550376, 'reg_lambda': 0.6088495034840391}. Best is trial 38 with value: 0.512859650164927.
# [I 2025-06-30 21:07:06,492] Trial 43 finished with value: 0.49909584056351447 and parameters: {'n_estimators': 192, 'learning_rate': 0.21352332157906234, 'num_leaves': 52, 'max_depth': 14, 'min_child_samples': 96, 'subsample': 0.6003618660425166, 'colsample_bytree': 0.5065713341474734, 'reg_alpha': 0.9884780979943804, 'reg_lambda': 0.8596990156583068}. Best is trial 38 with value: 0.512859650164927.
# [I 2025-06-30 21:07:19,546] Trial 44 finished with value: 0.5107735779339462 and parameters: {'n_estimators': 504, 'learning_rate': 0.015971137523830857, 'num_leaves': 41, 'max_depth': 14, 'min_child_samples': 81, 'subsample': 0.5245197374533164, 'colsample_bytree': 0.6858788982416933, 'reg_alpha': 0.30931662428565954, 'reg_lambda': 0.43760879894673005}. Best is trial 38 with value: 0.512859650164927.
# [I 2025-06-30 21:07:30,481] Trial 45 finished with value: 0.510064043618859 and parameters: {'n_estimators': 503, 'learning_rate': 0.016920259584795583, 'num_leaves': 44, 'max_depth': 14, 'min_child_samples': 66, 'subsample': 0.5216764383478635, 'colsample_bytree': 0.7076423338698258, 'reg_alpha': 0.11411695145126076, 'reg_lambda': 0.43043315335481086}. Best is trial 38 with value: 0.512859650164927.
# [I 2025-06-30 21:07:37,256] Trial 46 finished with value: 0.5117787383307569 and parameters: {'n_estimators': 318, 'learning_rate': 0.019545821632096654, 'num_leaves': 42, 'max_depth': 15, 'min_child_samples': 74, 'subsample': 0.5283137837290465, 'colsample_bytree': 0.6835440504294822, 'reg_alpha': 0.3159598206072284, 'reg_lambda': 0.731130941177549}. Best is trial 38 with value: 0.512859650164927.
# [I 2025-06-30 21:07:45,274] Trial 47 finished with value: 0.5119136259092802 and parameters: {'n_estimators': 302, 'learning_rate': 0.02041960443406866, 'num_leaves': 53, 'max_depth': 15, 'min_child_samples': 73, 'subsample': 0.5802021607497075, 'colsample_bytree': 0.7257168096928848, 'reg_alpha': 0.8691639153697445, 'reg_lambda': 0.7175712837365903}. Best is trial 38 with value: 0.512859650164927.
# [I 2025-06-30 21:07:56,584] Trial 48 finished with value: 0.5102865537018706 and parameters: {'n_estimators': 705, 'learning_rate': 0.020075004414047262, 'num_leaves': 27, 'max_depth': 15, 'min_child_samples': 65, 'subsample': 0.5936525511310977, 'colsample_bytree': 0.7894909591638615, 'reg_alpha': 0.9232498842300475, 'reg_lambda': 0.721681955989816}. Best is trial 38 with value: 0.512859650164927.
# [I 2025-06-30 21:08:02,818] Trial 49 finished with value: 0.5116514688053241 and parameters: {'n_estimators': 324, 'learning_rate': 0.02713331134523615, 'num_leaves': 37, 'max_depth': 15, 'min_child_samples': 75, 'subsample': 0.5003551705580824, 'colsample_bytree': 0.7216397020155015, 'reg_alpha': 0.8653438489827138, 'reg_lambda': 0.814264730073791}. Best is trial 38 with value: 0.512859650164927.
# Best params: {'n_estimators': 215, 'learning_rate': 0.016164681015374455, 'num_leaves': 33, 'max_depth': 14, 'min_child_samples': 100, 'subsample': 0.6421631816787918, 'colsample_bytree': 0.6570997703960657, 'reg_alpha': 0.13231170133425174, 'reg_lambda': 0.5282284076568279}
# Best F2 score: 0.512859650164927

# %%
# Train final LightGBM with best params

best_params = study.best_params
best_params['random_state'] = 42
best_params['n_jobs'] = -1

final_lgbm = LGBMClassifier(**best_params)
final_lgbm.fit(X_train_bal, y_train_bal)

# Validation predictions
y_val_prob_final = final_lgbm.predict_proba(X_val_scaled)[:,1]
best_thresh, best_f2 = find_best_threshold_f2(y_val, y_val_prob_final)
print(f"Best threshold: {best_thresh:.4f}, Best F2-score: {best_f2:.4f}")

y_val_pred_final = (y_val_prob_final >= best_thresh).astype(int)
print(classification_report(y_val, y_val_pred_final))
# Out:
# Best threshold: 0.4274, Best F2-score: 0.5129
#               precision    recall  f1-score   support
#
#            0       0.97      0.87      0.92     27995
#            1       0.26      0.67      0.38      2005
#
#     accuracy                           0.85     30000
#    macro avg       0.62      0.77      0.65     30000
# weighted avg       0.93      0.85      0.88     30000

# %%
# Prepare test set and make predictions
df_test_imputed = df_test.copy()
imputer = SimpleImputer(strategy='median')
df_test_imputed[['MonthlyIncome', 'NumberOfDependents']] = imputer.fit_transform(
    df_test_imputed[['MonthlyIncome', 'NumberOfDependents']]
)

# Preprocess test set same as train
X_test = df_test_imputed[features]
X_test_scaled = scaler.transform(X_test)

# Predict probabilities
y_test_prob = final_lgbm.predict_proba(X_test_scaled)[:, 1]

# Predict labels based on best threshold
y_test_pred = (y_test_prob >= best_thresh).astype(int)

# Prepare submission dataframe with only Id and prediction probability
submission = pd.DataFrame({
    'Id': df_submission['Id'],
    'Probability': y_test_prob
})

submission.to_csv('submission.csv', index=False)
print("Submission saved!")
# Out:
# Submission saved!

# %%
# Save the trained model
joblib.dump(final_lgbm, 'lgbm_credit_model.pkl')
print("Model saved as 'lgbm_credit_model.pkl'")
# Out:
# Model saved as 'lgbm_credit_model.pkl'
